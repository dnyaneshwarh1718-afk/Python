# %%
# 1. Write a Python program to get the Python version you are using. 
import sys
print("Python Version")
print(sys.version)
print("Version Info")
print(sys.version_info)
# Out:
# Python Version
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]
# Version Info
# sys.version_info(major=3, minor=13, micro=5, releaselevel='final', serial=0)

# %%
# 2. Write a Python program to display the current date and time.
import datetime
x = datetime.datetime.now()
print(x)
print(x.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2026-02-16 14:33:19.473183
# 2026-02-16 14:33:19

# %%
# 3. Write a Python program which accepts the radius of a circle from the user and compute the area. 
from math import pi
r = float(input("Enter a Radius of circle:"))
print("Area of the circle with radius" + str(r) + "is:"+ str(pi*r**2))
# Out:
# Enter a Radius of circle: 1.1
# Area of the circle with radius1.1is:3.8013271108436504

# %%
# 4.Write a Python program which accepts the user's first and last name and print them in reverse order with a space between them 
fname = input("Enter a First Name:")
lname = input("Enter a Last Name:")
print("Hello,"+ " " + lname + " " + fname)
# Out:
# Enter a First Name: Dnyaneshwar
# Enter a Last Name: Hiwale
# Hello, Hiwale Dnyaneshwar

# %%
# 5.Write a Python program which accepts a sequence of comma-separated numbers from user and generate a list and a tuple with those numbers
values = input("Enter a numbers:")
list1 = values.split(",")
tuple1 = tuple(list1)
print("List:",list1)
print("Tuple:",tuple1)
# Out:
# Enter a numbers: 1,2,3,4,5,8,4,5,4,4,4,4,4,
# List: ['1', '2', '3', '4', '5', '8', '4', '5', '4', '4', '4', '4', '4', '']
# Tuple: ('1', '2', '3', '4', '5', '8', '4', '5', '4', '4', '4', '4', '4', '')

# %%
# 6.Write a Python program to accept a filename from the user and print the extension of that. 
filename = input("INPUT THE FILENAME:")
f_extns = filename.split(".")
print("The extension of the file is :" + repr(f_extns[-1]))
# Out:
# INPUT THE FILENAME: abc.pdf
# The extension of the file is :'pdf'

# %%
# 7.Write a Python program to display the first and last colors from the following list.  
color_list = ["Red","Green","White" ,"Black"]

print("%s %s"%(color_list[0],color_list[-1]))
# Out:
# Red Black

# %%
# 8.Write a Python program that accepts an integer (n) and computes the value of n+nn+nnn. 
a = int(input("Enter an Integer:"))
n1 = int("%s"% a)
n2 = int("%s%s"% (a,a))
n3 = int("%s%s%s"%(a,a,a))
print(n1+n2+n3)
# Out:
# Enter an Integer: 5
# 615

# %%
# 9.Write a Python program to get the volume of a sphere with radius 6.
from math import pi
r = 6
v = 4.0/3.0*pi*r**3
print("The volume of the sphere is:",v)
# Out:
# The volume of the sphere is: 904.7786842338603

# %%
# 10. Write a Python program to convert seconds to day, hour, minutes and seconds.  
time = float(input("Input time in seconds: "))
day = time // (24 * 3600)
time = time % (24 * 3600)
hour = time // 3600
time %= 3600
minutes = time // 60
time %= 60
# Out:
# Input time in seconds:  6000000
